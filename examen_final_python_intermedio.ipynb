# %% [markdown]
# <a href="https://colab.research.google.com/github/PercyBenites/ACTIVIDAD_PYTHONINTERMEDIO_CTIC/blob/main/examen_final_python_intermedio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://www.ctic.uni.edu.pe/wp-content/uploads/2022/04/588px-x-348px-web-1.png" alt="HTML5 Icon" width="900" height="350" >

# %% [markdown]
# <h1 align=center><font size = 5>EXAMEN FINAL PYTHON INTERMEDIO
# </font></h1>
#
# ---

# %% [markdown]
# 1. **(2 Puntos)** ¿Qué es Pep 8? Describa su utilidad y un ejemplo de cómo utilizarla.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import argparse

# %%
La pep 8 es un documento que se utiliza para la identación, tamaño de linea y codificación mas legible.
# Out:
#   File "<ipython-input-2-76bc0232a330>", line 1
#     La pep 8 es un documento que se utiliza para la identación, tamaño de linea y codificación mas legible.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---
# 2. **(5 puntos)** Desarrolle una función que trabaje con argparse. Dicha función debe recibir como atributos debe recibir un tipo de animal y tratamiento y devolver como resultado el costo del servicio.
#
# **Lista de precios**
# > Corte de pelo
# *   Gato: 20
# *   Perro: 30
# *   Conejo: 15
#
# > Baño
# *   Gato: 15
# *   Perro: 20
# *   Conejo: 10
#
# > Desparasitación
# *   Gato: 35
# *   Perro: 50
# *   Conejo: 25

# %%
def muestra_datos(**kwargs):
    claves = type(kwargs.keys())
    valores = type(kwargs.values())
    
    print(claves)
    print(valores)
    
corte1 = {"gato":"15", "perro":"30", "conejo":"15"}

baño2 = {"gato":"15", "perro":"20", "conejo":"10"}

desparacitacion3 = {"gato":"35", "perro":"50", "conejo":"25"}

muestra_datos(**corte1)
muestra_datos(**baño2)
muestra_datos(**desparacitacion3)

# %% [markdown]
# ---
#
# 3. **(10 puntos)** Descargue la base de datos de casos positivos de covid del siguiente [enlace](https://www.datosabiertos.gob.pe/dataset/casos-positivos-por-covid-19-ministerio-de-salud-minsa) y carguelos en pandas, luego de esto grafique un gráfico de lineas que muestre la cantidad de casos mes a mes de positivos de covid en la región de Lima.

# %% [markdown]
# ![Captura de Pantalla 2023-03-04 a la(s) 21.24.04.png](data:image/png;base64,...)

# %%
covid = pd.read_csv('positivos_covid.csv',delimiter=';' )
covid.head()
# Out:
#    FECHA_CORTE DEPARTAMENTO PROVINCIA                DISTRITO METODODX  EDAD  \
# 0     20230308         LIMA      LIMA             EL AGUSTINO       PR  51.0
# 1     20230308     AREQUIPA  AREQUIPA                AREQUIPA      PCR  34.0
# 2     20230308         LIMA      LIMA       SANTIAGO DE SURCO       AG  35.0
# 3     20230308         LIMA      LIMA             JESUS MARIA       AG  20.0
# 4     20230308         LIMA      LIMA  SAN JUAN DE LURIGANCHO       AG  24.0
#
#         SEXO  FECHA_RESULTADO    UBIGEO  id_persona
# 0  MASCULINO       20200516.0  150111.0  13865972.0
# 1  MASCULINO       20220707.0   40101.0  13866130.0
# 2  MASCULINO       20221129.0  150140.0  13866165.0
# 3   FEMENINO       20210419.0  150113.0  13866369.0
# 4  MASCULINO       20221114.0  150132.0  13866398.0

# %%
covid['MES_RESULTADO'] = covid.FECHA_RESULTADO.apply(lambda x: str(x)[:6])
covid.head()
# Out:
#    FECHA_CORTE DEPARTAMENTO PROVINCIA                DISTRITO METODODX  EDAD  \
# 0     20230308         LIMA      LIMA             EL AGUSTINO       PR  51.0
# 1     20230308     AREQUIPA  AREQUIPA                AREQUIPA      PCR  34.0
# 2     20230308         LIMA      LIMA       SANTIAGO DE SURCO       AG  35.0
# 3     20230308         LIMA      LIMA             JESUS MARIA       AG  20.0
# 4     20230308         LIMA      LIMA  SAN JUAN DE LURIGANCHO       AG  24.0
#
#         SEXO  FECHA_RESULTADO    UBIGEO  id_persona MES_RESULTADO
# 0  MASCULINO       20200516.0  150111.0  13865972.0        202005
# 1  MASCULINO       20220707.0   40101.0  13866130.0        202207
# 2  MASCULINO       20221129.0  150140.0  13866165.0        202211
# 3   FEMENINO       20210419.0  150113.0  13866369.0        202104
# 4  MASCULINO       20221114.0  150132.0  13866398.0        202211

# %%
df = covid.groupby("MES_RESULTADO")[["id_persona"]].aggregate(['count']).reset_index()
df.columns = df.columns.droplevel(-1)
df.head()
# Out:
#   MES_RESULTADO  id_persona
# 0        202003        1195
# 1        202004       45235
# 2        202005      127840
# 3        202006      119880
# 4        202007      142388

# %%
import seaborn as sns
plt.rcParams["figure.figsize"] = (20, 6)
sns.lineplot(x="MES_RESULTADO", y="id_persona", data=df)
# Out:
# <AxesSubplot:xlabel='MES_RESULTADO', ylabel='id_persona'>

# %% [markdown]
# ---
#
# 4. **(3 puntos)** En el dataset de Titanic train [enlace](https://www.kaggle.com/c/titanic/overview) visto en clase, realice un gráfico de cajas sobre la variable Fare (Costo del ticket), ¿qué observa?, ¿Hay outliers?, ¿Qué tratamiento recomendaría?

# %%
pddf = pd.read_csv('train_titanic.csv')
pddf.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(data=pddf.Fare, orient="h")

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(data=pddf.Fare, orient="v")

# %% [markdown]
# ---
#
# # Gracias por completar este examen!
#
# ---
